# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')

# %%
# Load dataset
ins_data = pd.read_csv('insurance.csv')
ins_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# Basic overview
ins_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# Checking for missing values
ins_data.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Checking for duplicated rows
ins_data.duplicated().sum()
# Out:
# 1

# %%
# Drop duplicates
ins_data.drop_duplicates(inplace=True)

# %%
cat_cols = ins_data.select_dtypes('object').columns
num_cols = ins_data.select_dtypes(exclude='object').columns.difference(['charges'])
target_col = ['charges']

# %%
plt.figure(figsize=(4,3))
corr = ins_data[num_cols].corr()
sns.heatmap(corr, annot=True)
plt.title("Correlation", fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(9,7))
for index, i in enumerate(num_cols):
    plt.subplot(2,2, index+1)
    sns.histplot(x=i, data=ins_data, kde=True)
    plt.title(f"Distribution of {i}", fontweight='bold')
plt.tight_layout()

# %%
plt.figure(figsize=(9,7))
for index, i in enumerate(num_cols):
    plt.subplot(2,2, index+1)
    sns.histplot(x=i, data=ins_data, kde=True, hue='sex')
    plt.title(f"Distribution of {i}", fontweight='bold')
plt.tight_layout()

# %%
plt.figure(figsize=(9,7))
for index, i in enumerate(num_cols):
    plt.subplot(2,2, index+1)
    sns.histplot(x=i, data=ins_data, kde=True, hue='smoker')
    plt.title(f"Distribution of {i}", fontweight='bold')
plt.tight_layout()

# %%
plt.figure(figsize=(8,6))
for index, i in enumerate(cat_cols):
    plt.subplot(2,2,index+1)
    sns.countplot(x=i, data=ins_data)
    plt.title(f"Distribution of {i}", fontweight='bold')
plt.tight_layout()

# %%
plt.figure(figsize=(8,6))
for index, i in enumerate(cat_cols):
    plt.subplot(2,2,index+1)
    sns.boxplot(x=i,y='charges', data=ins_data)
    plt.title(f"Distribution of {i}", fontweight='bold')
plt.tight_layout()

# %%
ins_data[target_col].describe()
# Out:
#             charges
# count   1337.000000
# mean   13279.121487
# std    12110.359656
# min     1121.873900
# 25%     4746.344000
# 50%     9386.161300
# 75%    16657.717450
# max    63770.428010

# %%
sns.histplot(x= 'charges', data=ins_data, kde=True)
plt.title("DIstribution of Target", fontweight='bold')
plt.show()

# %%
sns.histplot(x= 'charges',hue='smoker', data=ins_data, kde=True)
plt.title("DIstribution of Target", fontweight='bold')
plt.show()

# %%
sns.histplot(x= 'charges',hue='sex', data=ins_data, kde=True)
plt.title("DIstribution of Target", fontweight='bold')
plt.show()
